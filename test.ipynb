# %%
import os
import pandas as pd
train_file = "C:/Users/dowon/data/소상공인 고객 주문 질의-응답 텍스트/Training/라벨링데이터_train"

file_lst = os.listdir(train_file)
# 현재 디렉토리내에 모든 파일 출력
os.chdir(train_file)
dfList=[]
for f_n in file_lst :
    print(f_n + ' 파일 ' + ' 불러오는 중...')
    try :
        dfList.append(pd.read_csv(f_n))
        
        #df = pd.DataFrame(raw_data['info'][0]['annotations']['lines'])
        #df_list.append(df)
    except Exception as e : 
        print("오류가 발생했습니다. 오류 메세지 :", e, ", 오류 파일명 :", f_n)
        pass
# Out:
# 가구인테리어_train.csv 파일  불러오는 중...
# C:\Users\dowon\AppData\Local\Temp\ipykernel_27448\1761613290.py:12: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfList.append(pd.read_csv(f_n))
# 건강_train.csv 파일  불러오는 중...
# 기타_train.csv 파일  불러오는 중...
# 디지털가전_train.csv 파일  불러오는 중...
# C:\Users\dowon\AppData\Local\Temp\ipykernel_27448\1761613290.py:12: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfList.append(pd.read_csv(f_n))
# 병원_train.csv 파일  불러오는 중...
# 뷰티_train.csv 파일  불러오는 중...
# 생활잡화_train.csv 파일  불러오는 중...
# C:\Users\dowon\AppData\Local\Temp\ipykernel_27448\1761613290.py:12: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfList.append(pd.read_csv(f_n))
# 슈퍼_train.csv 파일  불러오는 중...
# C:\Users\dowon\AppData\Local\Temp\ipykernel_27448\1761613290.py:12: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfList.append(pd.read_csv(f_n))
# 식품_train.csv 파일  불러오는 중...
# 음식점_train.csv 파일  불러오는 중...
# 의류_train.csv 파일  불러오는 중...
# 출산육아_train.csv 파일  불러오는 중...
# 카페_train.csv 파일  불러오는 중...
# 패션_train.csv 파일  불러오는 중...
# C:\Users\dowon\AppData\Local\Temp\ipykernel_27448\1761613290.py:12: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfList.append(pd.read_csv(f_n))

# %%
if dfList[0]['발화자'] == cdfList[0]
# Out:
#            IDX 발화자                                        발화문    카테고리   QA번호  \
# 0            1   c                                    러그 식이네요  가구인테리어    211
# 1            2   s                                          네  가구인테리어    211
# 2            3   c                               아까거랑 뭐가 달라요?  가구인테리어     10
# 3            4   s                          아까는 60수였어요 여긴 40수  가구인테리어     10
# 4            5   c                 아 요것도 괜찮고, 가격 면에서는 저것도 괜찮고  가구인테리어     50
# ...        ...  ..                                        ...     ...    ...
# 502794  502795   s                               참고하도록 하겠습니다.  가구인테리어  43323
# 502795  502796   c            제품 구매 전문의 드려요후 사고리는 구매할 수 없을까요?  가구인테리어  35528
# 502796  502797   s        후 사고리는 가까운 철물점이나 마트에서 구매하셔도 괜찮으십니다.  가구인테리어  35528
# 502797  502798   c                        오늘 구매해도 바디필로 우주시나요?  가구인테리어  77568
# 502798  502799   s  네. 사은품으로 증정되는 릴렉스 필로우는 합포장되어 받아보실 수 있습니다.  가구인테리어  77568
#
#        QA여부 감성       인텐트   가격   수량   크기   장소   조직   사람   시간   날짜      상품명  \
# 0         q  m  제품_일반_비교  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN       러그
# 1         a  m  제품_일반_비교  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN
# 2         q  m  제품_일반_비교  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN
# 3         a  m  제품_일반_비교  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN
# 4         q  m  제품_일반_비교  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN
# ...     ... ..       ...  ...  ...  ...  ...  ...  ...  ...  ...      ...
# 502794    a  m  제품_구매_질문  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      NaN
# 502795    q  m  제품_구매_질문  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    후 사고리
# 502796    a  m  제품_구매_질문  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN    후 사고리
# 502797    q  m  제품_구매_질문  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      바디필
# 502798    a  m  제품_구매_질문  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  릴렉스 필로우
#
#          상담번호  상담내순번
# 0         791    431
# 1         791    432
# 2        4353     21
# 3        4353     22
# 4        4791     98
# ...       ...    ...
# 502794  43323      2
# 502795  35528      1
# 502796  35528      2
# 502797  77568      1
# 502798  77568      2
#
# [502799 rows x 19 columns]
